# %%
# !pip install opendatasets

# %% [markdown]
# #### THE CODE WAS DONE IN GOOGLE COLAB

# %%
import opendatasets as od
import pandas
od.download("https://www.kaggle.com/datasets/vipoooool/new-plant-diseases-dataset")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: theraghavjuneja
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 2.70G/2.70G [00:39<00:00, 74.1MB/s]

# %%
import os

os.listdir('/content')
# Out:
# ['.config', 'new-plant-diseases-dataset', 'sample_data']

# %%
import os

dataset_path = '/content/new-plant-diseases-dataset'
os.listdir(dataset_path)
# Out:
# ['new plant diseases dataset(augmented)',
#  'New Plant Diseases Dataset(Augmented)',
#  'test']

# %%
import os

dataset_directory = '/content/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid'
os.listdir(dataset_directory)
# Out:
# ['Blueberry___healthy',
#  'Squash___Powdery_mildew',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Apple___Cedar_apple_rust',
#  'Tomato___healthy',
#  'Tomato___Bacterial_spot',
#  'Tomato___Septoria_leaf_spot',
#  'Corn_(maize)___healthy',
#  'Tomato___Late_blight',
#  'Potato___Early_blight',
#  'Grape___Esca_(Black_Measles)',
#  'Corn_(maize)___Common_rust_',
#  'Soybean___healthy',
#  'Apple___healthy',
#  'Cherry_(including_sour)___Powdery_mildew',
#  'Potato___healthy',
#  'Tomato___Early_blight',
#  'Apple___Black_rot',
#  'Tomato___Target_Spot',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Strawberry___Leaf_scorch',
#  'Potato___Late_blight',
#  'Peach___Bacterial_spot',
#  'Strawberry___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Tomato___Leaf_Mold',
#  'Raspberry___healthy',
#  'Tomato___Tomato_mosaic_virus',
#  'Grape___Black_rot',
#  'Pepper,_bell___Bacterial_spot',
#  'Grape___healthy',
# ...

# %% [markdown]
# ### I HAVE 3 SORTS OF DATASET TRAIN , TEST AND VALID

# %%
validation_set='/content/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid'
os.listdir(validation_set)
# Out:
# ['Blueberry___healthy',
#  'Squash___Powdery_mildew',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Apple___Cedar_apple_rust',
#  'Tomato___healthy',
#  'Tomato___Bacterial_spot',
#  'Tomato___Septoria_leaf_spot',
#  'Corn_(maize)___healthy',
#  'Tomato___Late_blight',
#  'Potato___Early_blight',
#  'Grape___Esca_(Black_Measles)',
#  'Corn_(maize)___Common_rust_',
#  'Soybean___healthy',
#  'Apple___healthy',
#  'Cherry_(including_sour)___Powdery_mildew',
#  'Potato___healthy',
#  'Tomato___Early_blight',
#  'Apple___Black_rot',
#  'Tomato___Target_Spot',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Strawberry___Leaf_scorch',
#  'Potato___Late_blight',
#  'Peach___Bacterial_spot',
#  'Strawberry___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Tomato___Leaf_Mold',
#  'Raspberry___healthy',
#  'Tomato___Tomato_mosaic_virus',
#  'Grape___Black_rot',
#  'Pepper,_bell___Bacterial_spot',
#  'Grape___healthy',
# ...

# %%
import tensorflow as tf

physical_devices = tf.config.experimental.list_physical_devices()
for device in physical_devices:
    print(device)
# Out:
# PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
with tf.device("/device:GPU:0"):
  print("Hello")
with tf.device("/device:CPU:0"):
  print("Hello")
# Out:
# Hello
# Hello

# %%
validation_set='/content/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid'
os.listdir(validation_set)
# Out:
# ['Blueberry___healthy',
#  'Squash___Powdery_mildew',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Apple___Cedar_apple_rust',
#  'Tomato___healthy',
#  'Tomato___Bacterial_spot',
#  'Tomato___Septoria_leaf_spot',
#  'Corn_(maize)___healthy',
#  'Tomato___Late_blight',
#  'Potato___Early_blight',
#  'Grape___Esca_(Black_Measles)',
#  'Corn_(maize)___Common_rust_',
#  'Soybean___healthy',
#  'Apple___healthy',
#  'Cherry_(including_sour)___Powdery_mildew',
#  'Potato___healthy',
#  'Tomato___Early_blight',
#  'Apple___Black_rot',
#  'Tomato___Target_Spot',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Strawberry___Leaf_scorch',
#  'Potato___Late_blight',
#  'Peach___Bacterial_spot',
#  'Strawberry___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Tomato___Leaf_Mold',
#  'Raspberry___healthy',
#  'Tomato___Tomato_mosaic_virus',
#  'Grape___Black_rot',
#  'Pepper,_bell___Bacterial_spot',
#  'Grape___healthy',
# ...

# %%
training_set='/content/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train'
os.listdir(training_set)
# Out:
# ['Blueberry___healthy',
#  'Squash___Powdery_mildew',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Apple___Cedar_apple_rust',
#  'Tomato___healthy',
#  'Tomato___Bacterial_spot',
#  'Tomato___Septoria_leaf_spot',
#  'Corn_(maize)___healthy',
#  'Tomato___Late_blight',
#  'Potato___Early_blight',
#  'Grape___Esca_(Black_Measles)',
#  'Corn_(maize)___Common_rust_',
#  'Soybean___healthy',
#  'Apple___healthy',
#  'Cherry_(including_sour)___Powdery_mildew',
#  'Potato___healthy',
#  'Tomato___Early_blight',
#  'Apple___Black_rot',
#  'Tomato___Target_Spot',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Strawberry___Leaf_scorch',
#  'Potato___Late_blight',
#  'Peach___Bacterial_spot',
#  'Strawberry___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Tomato___Leaf_Mold',
#  'Raspberry___healthy',
#  'Tomato___Tomato_mosaic_virus',
#  'Grape___Black_rot',
#  'Pepper,_bell___Bacterial_spot',
#  'Grape___healthy',
# ...

# %%
testing_set='/content/new-plant-diseases-dataset/test/test'
os.listdir(testing_set)
# Out:
# ['PotatoEarlyBlight3.JPG',
#  'AppleCedarRust3.JPG',
#  'CornCommonRust2.JPG',
#  'AppleScab3.JPG',
#  'TomatoHealthy1.JPG',
#  'AppleCedarRust4.JPG',
#  'PotatoEarlyBlight1.JPG',
#  'CornCommonRust1.JPG',
#  'TomatoHealthy2.JPG',
#  'AppleCedarRust1.JPG',
#  'TomatoYellowCurlVirus3.JPG',
#  'TomatoEarlyBlight1.JPG',
#  'TomatoYellowCurlVirus2.JPG',
#  'PotatoHealthy2.JPG',
#  'TomatoEarlyBlight3.JPG',
#  'TomatoYellowCurlVirus6.JPG',
#  'TomatoEarlyBlight6.JPG',
#  'TomatoHealthy3.JPG',
#  'TomatoHealthy4.JPG',
#  'TomatoEarlyBlight4.JPG',
#  'PotatoEarlyBlight5.JPG',
#  'PotatoEarlyBlight2.JPG',
#  'TomatoYellowCurlVirus1.JPG',
#  'AppleCedarRust2.JPG',
#  'CornCommonRust3.JPG',
#  'PotatoEarlyBlight4.JPG',
#  'AppleScab2.JPG',
#  'TomatoEarlyBlight5.JPG',
#  'AppleScab1.JPG',
#  'TomatoYellowCurlVirus5.JPG',
#  'TomatoEarlyBlight2.JPG',
#  'TomatoYellowCurlVirus4.JPG',
#  'PotatoHealthy1.JPG']

# %%
view_image='/content/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid/Blueberry___healthy/0b344c16-456c-4085-aa61-6a1c4cb93632___RS_HL 2538.JPG'
img=mpimg.imread(view_image)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ### IN SHORT I HAVE 3 DIRECTORIES TRAIN, TEST AND VALID WHERE I HAVE IMAGED TO VIEW AS SIMPLE AS THAT

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Directory paths
train_dir = '/content/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train'
validation_dir = '/content/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid'

# reducing image size to 150,150
batch_size = 32
image_size = (150, 150)


train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical')

# using a sequential model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    #Since number of classes=38
    tf.keras.layers.Dense(38, activation='softmax')
])

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])


history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=10,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size
)
# Out:
# Found 70295 images belonging to 38 classes.
# Found 17572 images belonging to 38 classes.
# Epoch 1/10
# 2196/2196 [==============================] - 130s 56ms/step - loss: 1.0105 - accuracy: 0.6959 - val_loss: 0.4361 - val_accuracy: 0.8621
# Epoch 2/10
# 2196/2196 [==============================] - 124s 56ms/step - loss: 0.3076 - accuracy: 0.9003 - val_loss: 0.3152 - val_accuracy: 0.8954
# Epoch 3/10
# 2196/2196 [==============================] - 122s 55ms/step - loss: 0.1940 - accuracy: 0.9355 - val_loss: 0.2241 - val_accuracy: 0.9255
# Epoch 4/10
# 2196/2196 [==============================] - 122s 55ms/step - loss: 0.1401 - accuracy: 0.9529 - val_loss: 0.2230 - val_accuracy: 0.9280
# Epoch 5/10
# 2196/2196 [==============================] - 122s 55ms/step - loss: 0.1086 - accuracy: 0.9637 - val_loss: 0.1982 - val_accuracy: 0.9414
# Epoch 6/10
# 2196/2196 [==============================] - 118s 54ms/step - loss: 0.0934 - accuracy: 0.9693 - val_loss: 0.1941 - val_accuracy: 0.9406
# ...

# %%
model.summary()

# %%
dir(history)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_chief_worker_only',
#  '_implements_predict_batch_hooks',
#  '_implements_test_batch_hooks',
#  '_implements_train_batch_hooks',
#  '_keras_api_names',
#  '_keras_api_names_v1',
#  '_supports_tf_logs',
#  'epoch',
#  'history',
#  'model',
#  'on_batch_begin',
#  'on_batch_end',
#  'on_epoch_begin',
#  'on_epoch_end',
#  'on_predict_batch_begin',
#  'on_predict_batch_end',
#  'on_predict_begin',
#  'on_predict_end',
#  'on_test_batch_begin',
#  'on_test_batch_end',
#  'on_test_begin',
#  'on_test_end',
#  'on_train_batch_begin',
#  'on_train_batch_end',
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
os.listdir()
# Out:
# ['.config', 'new-plant-diseases-dataset', 'sample_data']

# %%
test='/content/new-plant-diseases-dataset/test/test'
os.listdir(test)
# Out:
# ['PotatoEarlyBlight3.JPG',
#  'AppleCedarRust3.JPG',
#  'CornCommonRust2.JPG',
#  'AppleScab3.JPG',
#  'TomatoHealthy1.JPG',
#  'AppleCedarRust4.JPG',
#  'PotatoEarlyBlight1.JPG',
#  'CornCommonRust1.JPG',
#  'TomatoHealthy2.JPG',
#  'AppleCedarRust1.JPG',
#  'TomatoYellowCurlVirus3.JPG',
#  'TomatoEarlyBlight1.JPG',
#  'TomatoYellowCurlVirus2.JPG',
#  'PotatoHealthy2.JPG',
#  'TomatoEarlyBlight3.JPG',
#  'TomatoYellowCurlVirus6.JPG',
#  'TomatoEarlyBlight6.JPG',
#  'TomatoHealthy3.JPG',
#  'TomatoHealthy4.JPG',
#  'TomatoEarlyBlight4.JPG',
#  'PotatoEarlyBlight5.JPG',
#  'PotatoEarlyBlight2.JPG',
#  'TomatoYellowCurlVirus1.JPG',
#  'AppleCedarRust2.JPG',
#  'CornCommonRust3.JPG',
#  'PotatoEarlyBlight4.JPG',
#  'AppleScab2.JPG',
#  'TomatoEarlyBlight5.JPG',
#  'AppleScab1.JPG',
#  'TomatoYellowCurlVirus5.JPG',
#  'TomatoEarlyBlight2.JPG',
#  'TomatoYellowCurlVirus4.JPG',
#  'PotatoHealthy1.JPG']

# %%
import os

testing_set = '/content/new-plant-diseases-dataset/test/'
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    testing_set,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)

# Evaluate the model on the test data
evaluation = model.evaluate(test_generator)

print("Test Accuracy:", evaluation[1])
# Out:
# Found 33 images belonging to 1 classes.
# 2/2 [==============================] - 1s 628ms/step - loss: 1677.0747 - accuracy: 0.0606
# Test Accuracy: 0.06060606241226196

# %%
# import numpy as np

# test_generator.reset()


# predictions = model.predict(test_generator)

# true_labels = test_generator.classes

# class_labels = {v: k for k, v in train_generator.class_indices.items()}

# for i, prediction in enumerate(predictions):
#     predicted_class = np.argmax(prediction)
#     true_class = true_labels[i]
#     print(f"Predicted: {class_labels[predicted_class]}, True: {class_labels[true_class]}")
# Out:
# 2/2 [==============================] - 0s 7ms/step
# Predicted: Apple___Cedar_apple_rust, True: Apple___Apple_scab
# Predicted: Apple___Cedar_apple_rust, True: Apple___Apple_scab
# Predicted: Apple___Cedar_apple_rust, True: Apple___Apple_scab
# Predicted: Apple___Cedar_apple_rust, True: Apple___Apple_scab
# Predicted: Apple___Apple_scab, True: Apple___Apple_scab
# Predicted: Apple___Apple_scab, True: Apple___Apple_scab
# Predicted: Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot, True: Apple___Apple_scab
# Predicted: Corn_(maize)___Common_rust_, True: Apple___Apple_scab
# Predicted: Corn_(maize)___Common_rust_, True: Apple___Apple_scab
# Predicted: Corn_(maize)___Common_rust_, True: Apple___Apple_scab
# Predicted: Potato___Early_blight, True: Apple___Apple_scab
# Predicted: Potato___Early_blight, True: Apple___Apple_scab
# Predicted: Soybean___healthy, True: Apple___Apple_scab
# Predicted: Potato___Early_blight, True: Apple___Apple_scab
# ...

# %%
model_save_path = '/path/to/save/model.h5'


model.save(model_save_path)

print("Model saved successfully at:", model_save_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved successfully at: /path/to/save/model.h5

# %%
from google.colab import files

model_save_path = '/content/model.h5'


model.save(model_save_path)

files.download(model_save_path)

# %%
from tensorflow.keras.models import load_model


loaded_model = load_model('/content/model.h5')


loaded_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 17, 17, 128)       0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 7, 7, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 38)                19494
#
# ...
# Total params: 3472102 (13.25 MB)
# Trainable params: 3472102 (13.25 MB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
model.evaluate(train_generator)
# Out:
# 2197/2197 [==============================] - 98s 45ms/step - loss: 0.0315 - accuracy: 0.9896
# [0.031464435160160065, 0.9895867705345154]

# %%
model.evaluate(validation_generator)
# Out:
# 550/550 [==============================] - 24s 44ms/step - loss: 0.2309 - accuracy: 0.9431
# [0.23090484738349915, 0.9431481957435608]

# %%
model.save("train_model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
history.history
# Out:
# {'loss': [1.010542392730713,
#   0.307609885931015,
#   0.19398264586925507,
#   0.14014725387096405,
#   0.10855548828840256,
#   0.09341824054718018,
#   0.07808179408311844,
#   0.07141537964344025,
#   0.06960716843605042,
#   0.059834498912096024],
#  'accuracy': [0.6958569884300232,
#   0.9002746939659119,
#   0.9354994893074036,
#   0.9529339671134949,
#   0.9637362360954285,
#   0.9693295359611511,
#   0.9745954275131226,
#   0.976858377456665,
#   0.9780254364013672,
#   0.9817115664482117],
#  'val_loss': [0.4361322224140167,
#   0.3151673972606659,
#   0.22414042055606842,
#   0.22295071184635162,
#   0.19816844165325165,
#   0.1940544694662094,
#   0.301788330078125,
#   0.20501038432121277,
#   0.29289138317108154,
#   0.23095403611660004],
#  'val_accuracy': [0.8621357083320618,
#   0.8954348564147949,
#   0.9254895448684692,
#   0.9279940724372864,
#   0.9414275884628296,
#   0.9405737519264221,
#   0.9218465685844421,
#   0.9446721076965332,
#   0.9297017455101013,
# ...

# %%
#MODEL HISTORY IN JSON

# %%
import json
with open("training_hist.json","w") as f:
  json.dump(history.history,f)

# %%
val_class=os.listdir(validation_set)

# %%
print(type(val_class))
# Out:
# <class 'list'>

# %%
for index,cls in enumerate(val_class):
  print(index,end=" ")
  print(cls)
# Out:
# 0 Blueberry___healthy
# 1 Squash___Powdery_mildew
# 2 Grape___Leaf_blight_(Isariopsis_Leaf_Spot)
# 3 Apple___Cedar_apple_rust
# 4 Tomato___healthy
# 5 Tomato___Bacterial_spot
# 6 Tomato___Septoria_leaf_spot
# 7 Corn_(maize)___healthy
# 8 Tomato___Late_blight
# 9 Potato___Early_blight
# 10 Grape___Esca_(Black_Measles)
# 11 Corn_(maize)___Common_rust_
# 12 Soybean___healthy
# 13 Apple___healthy
# 14 Cherry_(including_sour)___Powdery_mildew
# 15 Potato___healthy
# 16 Tomato___Early_blight
# 17 Apple___Black_rot
# 18 Tomato___Target_Spot
# 19 Corn_(maize)___Northern_Leaf_Blight
# 20 Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot
# 21 Strawberry___Leaf_scorch
# 22 Potato___Late_blight
# 23 Peach___Bacterial_spot
# 24 Strawberry___healthy
# 25 Orange___Haunglongbing_(Citrus_greening)
# 26 Tomato___Leaf_Mold
# 27 Raspberry___healthy
# 28 Tomato___Tomato_mosaic_virus
# 29 Grape___Black_rot
# 30 Pepper,_bell___Bacterial_spot
# 31 Grape___healthy
# ...

# %%
os.listdir(test)
# Out:
# ['PotatoEarlyBlight3.JPG',
#  'AppleCedarRust3.JPG',
#  'CornCommonRust2.JPG',
#  'AppleScab3.JPG',
#  'TomatoHealthy1.JPG',
#  'AppleCedarRust4.JPG',
#  'PotatoEarlyBlight1.JPG',
#  'CornCommonRust1.JPG',
#  'TomatoHealthy2.JPG',
#  'AppleCedarRust1.JPG',
#  'TomatoYellowCurlVirus3.JPG',
#  'TomatoEarlyBlight1.JPG',
#  'TomatoYellowCurlVirus2.JPG',
#  'PotatoHealthy2.JPG',
#  'TomatoEarlyBlight3.JPG',
#  'TomatoYellowCurlVirus6.JPG',
#  'TomatoEarlyBlight6.JPG',
#  'TomatoHealthy3.JPG',
#  'TomatoHealthy4.JPG',
#  'TomatoEarlyBlight4.JPG',
#  'PotatoEarlyBlight5.JPG',
#  'PotatoEarlyBlight2.JPG',
#  'TomatoYellowCurlVirus1.JPG',
#  'AppleCedarRust2.JPG',
#  'CornCommonRust3.JPG',
#  'PotatoEarlyBlight4.JPG',
#  'AppleScab2.JPG',
#  'TomatoEarlyBlight5.JPG',
#  'AppleScab1.JPG',
#  'TomatoYellowCurlVirus5.JPG',
#  'TomatoEarlyBlight2.JPG',
#  'TomatoYellowCurlVirus4.JPG',
#  'PotatoHealthy1.JPG']

# %% [markdown]
# #### TEST FOLDER HAS SOME RANDOM IMAGES,IT IS NOT HAVING ANY DIRECTORY SO I CAN'T USE IT DIRECTLY

# %%
print(batch_size)
print(image_size)
# Out:
# 32
# (150, 150)

# %%
test_generator = test_datagen.flow_from_directory(
    validation_set,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 17572 images belonging to 38 classes.

# %%
predicted_y_value=model.predict(test_generator)
# Out:
# 550/550 [==============================] - 27s 50ms/step

# %%
rows,columns=predicted_y_value.shape
print("Number of rows",rows)
print("Number of columns",columns)
# Out:
# Number of rows 17572
# Number of columns 38

# %%
predicted_y_value
# Out:
# array([[9.9974281e-01, 1.4391385e-11, 3.2077418e-12, ..., 1.3751171e-19,
#         1.4348906e-14, 8.7318719e-10],
#        [1.0000000e+00, 9.2911623e-10, 6.3891574e-12, ..., 7.7282755e-26,
#         1.7419198e-17, 7.4912585e-15],
#        [1.0000000e+00, 2.7542703e-16, 2.5512807e-16, ..., 6.0317325e-32,
#         1.7741967e-25, 1.2133360e-17],
#        ...,
#        [2.5408198e-08, 5.9570318e-22, 5.4278643e-10, ..., 3.1857117e-15,
#         1.3648632e-14, 9.8974520e-01],
#        [2.2279847e-12, 4.1418564e-27, 6.4412112e-15, ..., 2.0972748e-15,
#         1.4333103e-20, 1.0000000e+00],
#        [2.9586866e-23, 2.2766441e-23, 4.1150541e-23, ..., 2.1415748e-23,
#         1.7590306e-18, 9.9998319e-01]], dtype=float32)

# %%
import numpy as np

# %%
predicted_classes = np.argmax(predicted_y_value, axis=1)

# %%
predicted_classes
# Out:
# array([ 0,  0,  0, ..., 37, 37, 37])

# %%
true_classes = tf.concat([y for x, y in test_generator], axis=0)

# Print the true classes
print(true_classes)
